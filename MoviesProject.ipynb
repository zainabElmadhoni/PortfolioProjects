# %%
import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib 
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-06cb3473-7cf7-48bc-aa2b-322a05c34b92" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-06cb3473-7cf7-48bc-aa2b-322a05c34b92">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving movies.csv to movies.csv

# %%
df = pd.read_csv(r'./movies.csv', encoding = "ISO-8859-1")
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6820 entries, 0 to 6819
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   budget    6820 non-null   float64
#  1   company   6820 non-null   object
#  2   country   6820 non-null   object
#  3   director  6820 non-null   object
#  4   genre     6820 non-null   object
#  5   gross     6820 non-null   float64
#  6   name      6820 non-null   object
#  7   rating    6820 non-null   object
#  8   released  6820 non-null   object
#  9   runtime   6820 non-null   int64
#  10  score     6820 non-null   float64
#  11  star      6820 non-null   object
#  12  votes     6820 non-null   int64
#  13  writer    6820 non-null   object
#  14  year      6820 non-null   int64
# dtypes: float64(3), int64(3), object(9)
# memory usage: 799.3+ KB
#        budget                                 company  ...         writer  year
# 0   8000000.0           Columbia Pictures Corporation  ...   Stephen King  1986
# 1   6000000.0                      Paramount Pictures  ...    John Hughes  1986
# 2  15000000.0                      Paramount Pictures  ...       Jim Cash  1986
# 3  18500000.0  Twentieth Century Fox Film Corporation  ...  James Cameron  1986
# 4   9000000.0                    Walt Disney Pictures  ...  Mark H. Baker  1986
#
# [5 rows x 15 columns]

# %%
#Checking for missing data
for col in df.columns : 
  prct_missing = np.mean(df[col].isnull())
  print('{} - {}%'.format(col,prct_missing))
# Out:
# budget - 0.0%
# company - 0.0%
# country - 0.0%
# director - 0.0%
# genre - 0.0%
# gross - 0.0%
# name - 0.0%
# rating - 0.0%
# released - 0.0%
# runtime - 0.0%
# score - 0.0%
# star - 0.0%
# votes - 0.0%
# writer - 0.0%
# year - 0.0%

# %%
# data types for our columns

df.dtypes
# Out:
# budget      float64
# company      object
# country      object
# director     object
# genre        object
# gross       float64
# name         object
# rating       object
# released     object
# runtime       int64
# score       float64
# star         object
# votes         int64
# writer       object
# year          int64
# dtype: object

# %%
#Change data type of columns
df['budget'] = df['budget'].astype('int64')

df['gros'] = df['gross'].astype('int64')

# %%
df.head()
# Out:
#      budget                                 company  ...  year       gros
# 0   8000000           Columbia Pictures Corporation  ...  1986   52287414
# 1   6000000                      Paramount Pictures  ...  1986   70136369
# 2  15000000                      Paramount Pictures  ...  1986  179800601
# 3  18500000  Twentieth Century Fox Film Corporation  ...  1986   85160248
# 4   9000000                    Walt Disney Pictures  ...  1986   18564613
#
# [5 rows x 16 columns]

# %%
#Create correct year
df['correctYear'] = df['released'].astype(str).str[:4]

# %%
pd.set_option('display.max_rows', None)

# %%
df.sort_values(by=['gross'], inplace=False, ascending=False).head()
# Out:
#          budget  company  country  ...  year       gros  correctYear
# 6380  245000000     1428       54  ...  2015  936662225           29
# 5061  237000000     2062       53  ...  2009  760507625           23
# 2420  200000000     2062       54  ...  1997  658672302           11
# 6391  150000000     2085       54  ...  2015  652270625           29
# 5723  220000000     1491       54  ...  2012  623357910           26
#
# [5 rows x 17 columns]

# %%
# Scatter Plot with budget vs gross

plt.scatter(x=df['budget'],y=df['gross'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('budget')
plt.ylabel('Gross')
plt.show()

# %%
# Plot budget vs Gross using seaborn

sns.regplot(x='budget', y='gross', data=df, scatter_kws={"color" : "blue"}, line_kws={"color": "red"})

# %%
df.corr(method='pearson')
# Out:
#            budget     gross   runtime     score     votes      year      gros
# budget   1.000000  0.712196  0.268226  0.042145  0.503924  0.291009  0.712196
# gross    0.712196  1.000000  0.224579  0.165693  0.662457  0.191548  1.000000
# runtime  0.268226  0.224579  1.000000  0.395343  0.317399  0.087639  0.224579
# score    0.042145  0.165693  0.395343  1.000000  0.393607  0.105276  0.165693
# votes    0.503924  0.662457  0.317399  0.393607  1.000000  0.229304  0.662457
# year     0.291009  0.191548  0.087639  0.105276  0.229304  1.000000  0.191548
# gros     0.712196  1.000000  0.224579  0.165693  0.662457  0.191548  1.000000

# %%
correlation_matrix = df.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
# Out:
# Text(87.0, 0.5, 'Movie Features')

# %%
#Look at Company
df_numerized = df

for col_name in df_numerized.columns:
  if(df_numerized[col_name].dtype == 'object'):
    df_numerized[col_name] = df_numerized[col_name].astype('category')
    df_numerized[col_name] = df_numerized[col_name].cat.codes
df_numerized.head()
# Out:
#      budget  company  country  director  ...  writer  year       gros  correctYear
# 0   8000000      665       54      2192  ...    3716  1986   52287414            0
# 1   6000000     1680       54      1296  ...    1970  1986   70136369            0
# 2  15000000     1680       54      2645  ...    1852  1986  179800601            0
# 3  18500000     2062       54      1066  ...    1629  1986   85160248            0
# 4   9000000     2122       54      2123  ...    2549  1986   18564613            0
#
# [5 rows x 17 columns]

# %%
correlation_matrix = df_numerized.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
# Out:
# Text(87.0, 0.5, 'Movie Features')

# %%
correlation_mat = df_numerized.corr()
corr_pairs = correlation_mat.unstack()
sorted_pairs = corr_pairs.sort_values()
sorted_pairs  = sorted_pairs[(sorted_pairs) > 0.5 ]
high_corr  = sorted_pairs[(sorted_pairs) <1 ]
high_corr
# Out:
# budget       votes          0.503924
# votes        budget         0.503924
#              gross          0.662457
# gross        votes          0.662457
# gros         votes          0.662457
# votes        gros           0.662457
# budget       gros           0.712196
# gross        budget         0.712196
# budget       gross          0.712196
# gros         budget         0.712196
# year         released       0.996187
# released     year           0.996187
# year         correctYear    0.996229
# correctYear  year           0.996229
#              released       0.999389
# released     correctYear    0.999389
# dtype: float64
